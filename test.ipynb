# %%
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.firefox import GeckoDriverManager
import time

def setup_driver():
    options = Options()
    options.add_argument("--disable-gpu")  # Desativa a aceleração de hardware
    options.add_argument("--disable-extensions")  # Desativa as extensões
    options.add_argument("--no-sandbox")  # Desativa o modo sandbox para o Selenium
    options.page_load_strategy = 'normal'  # Estratégia de carregamento: espera a carga completa

    service = Service(executable_path=GeckoDriverManager().install())
    driver = webdriver.Firefox(service=service, options=options)
    return driver

def login_unimed(driver):
    url = "https://segurosunimed.planium.io/web/login/entrar?logout=1"
    driver.get(url)

    # Adiciona um tempo de espera explícito para carregamento de scripts
    # time.sleep(10)  # Ajuste conforme a necessidade para garantir que todos os scripts sejam carregados

    # try:
    #     input_username_xpath = "/html/body/div[1]/div[3]/main/div/div[4]/div[1]/div[1]/form/div[1]/input"
    #     input_password_xpath = "/html/body/div[1]/div[3]/main/div/div[4]/div[1]/div[1]/form/div[2]/div/input"
    #     login_button_xpath = "/html/body/div[1]/div[3]/main/div/div[4]/div[1]/div[1]/form/a"

    #     driver.find_element(By.XPATH, input_username_xpath).send_keys("394803238699456366000144")
    #     driver.find_element(By.XPATH, input_password_xpath).send_keys("Abs@2023Saude#")
    #     driver.find_element(By.XPATH, login_button_xpath).click()

    #     time.sleep(5)
    #     print("Login realizado com sucesso!")
    # except Exception as e:
    #     print(f"Erro durante o login: {e}")

def main():
    driver = setup_driver()
    login_unimed(driver)
    # driver.quit()

if __name__ == "__main__":
    main()
# Out:
# A execução de células com 'Python 3.11.9' requer o pacote ipykernel.
#
# Execute o seguinte comando para instalar "ipykernel" no ambiente do Python.
#
# Comando: ""c:/Users/Felipe Fernandes/AppData/Local/Microsoft/WindowsApps/python3.11.exe" -m pip install ipykernel -U --user --force-reinstall"
